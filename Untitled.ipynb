# %%
import sys
import time
import re
import requests
import pandas as pd
from datetime import date
from pathlib import Path
from bs4 import BeautifulSoup
from urllib.parse import urljoin

sys.path.insert(0, "_src")
from financial_tools import FMPClient

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)

# --- Configuration ---
output_dir = Path("sec_filings_8k") / date.today().strftime("%Y-%m-%d")
output_dir.mkdir(parents=True, exist_ok=True) 

# --- Instantiate the Classes ---
client1 = FMPClient()
filings_8k = client1.get_data('sec-filings-8k', "ALL")
# Out:
# https://financialmodelingprep.com/stable/sec-filings-8k?&from=2026-05-22&to=2026-05-24&page=0&limit=1000&apikey=5nTvG2lrPgVl9QBo7AadhieWKbjUQtUm
#    Fetching sec-filings-8k for ALL...

# %%
pd.DataFrame(filings_8k).to_csv(output_dir / "filings_8k.csv", index=False)

SEC_BASE = "https://www.sec.gov"

session = requests.Session()
session.headers.update({
    "User-Agent": "Dave Zhuo zhuo.longhao@gmail.com",
    "Accept-Encoding": "gzip, deflate",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
})

def download_sec_html(url, timeout=(5, 20)):
    # Added Rate Limit Protection
    for attempt in range(3):
        r = session.get(url, timeout=timeout)
        if r.status_code == 429:
            print("⚠️ Rate limited by SEC. Sleeping for 10 seconds...")
            time.sleep(10)
            continue
        r.raise_for_status()
        return r.text
    raise Exception(f"Failed to fetch {url} after 3 attempts.")

def html_to_clean_text(html):
    soup = BeautifulSoup(html, "html.parser")
    for tag in soup(["script", "style", "noscript", "nav", "header", "footer"]):
        tag.decompose()
    text = soup.get_text(" ", strip=True)
    text = re.sub(r"\s+", " ", text)
    return text

def extract_sec_documents(filing_detail_url, filing_detail_html):
    soup = BeautifulSoup(filing_detail_html, "html.parser")
    docs = []
    table = soup.find("table", class_="tableFile", summary="Document Format Files")
    if not table:
        return docs
    rows = table.find_all("tr")[1:]
    for row in rows:
        cells = row.find_all("td")
        if len(cells) < 5:
            continue
        seq = cells[0].get_text(" ", strip=True)
        description = cells[1].get_text(" ", strip=True)
        document_cell = cells[2]
        doc_type = cells[3].get_text(" ", strip=True)
        size = cells[4].get_text(" ", strip=True)
        a = document_cell.find("a")
        if not a:
            continue
        href = a.get("href")
        document_name = a.get_text(" ", strip=True)
        if href.startswith("/ix?doc="):
            href = href.replace("/ix?doc=", "")
        full_url = urljoin(SEC_BASE, href)
        docs.append({
            "seq": seq, "description": description, "document": document_name,
            "type": doc_type, "size": size, "url": full_url,
        })
    return docs

def has_keywords_in_text(text):
    text = text.lower()
    keywords = [
        "credit agreement", "amended and restated credit agreement",
        "loan agreement", "revolving credit facility", "term loan",
        "entry into a material definitive agreement", "item 1.01",
    ]
    return any(keyword in text for keyword in keywords)

def search_actual_sec_documents(filing_detail_url):
    index_html = download_sec_html(filing_detail_url)
    docs = extract_sec_documents(filing_detail_url, index_html)
    results = []
    for doc in docs:
        doc_type = doc["type"].upper()
        if doc_type not in ["8-K", "EX-10.1", "EX-10.2", "EX-99.1"]:
            continue
        try:
            html = download_sec_html(doc["url"])
            text = html_to_clean_text(html)
            matched = has_keywords_in_text(text)
            results.append({
                "type": doc["type"], "description": doc["description"],
                "document": doc["document"], "url": doc["url"],
                "matched": matched, "text": text,
            })
            time.sleep(0.2)
        except Exception as e:
            results.append({
                "type": doc["type"], "description": doc["description"],
                "document": doc["document"], "url": doc["url"],
                "matched": False, "text": "", "error": str(e),
            })
    return results

all_results = []
for i, filing in enumerate(filings_8k, start=1):
    symbol = filing.get("symbol")
    filing_date = filing.get("filingDate")
    filing_detail_url = filing.get("link")
    print(f"[{i}/{len(filings_8k)}] Assessing: {symbol} | {filing_date}")
    try:
        doc_results = search_actual_sec_documents(filing_detail_url)
        matched_docs = [r for r in doc_results if r["matched"]]
        for r in doc_results:
            all_results.append({
                "symbol": symbol, "filingDate": filing_date,
                "filing_detail_url": filing_detail_url, "document_type": r.get("type"),
                "document_description": r.get("description"), "document_url": r.get("url"),
                "matched": r.get("matched"), "error": r.get("error"),
            })
        if matched_docs:
            print(f"  MATCH: {len(matched_docs)} document(s)")
        else:
            print("  No match")
    except Exception as e:
        print(f"  ERROR: {e}")
        all_results.append({
            "symbol": symbol, "filingDate": filing_date, "filing_detail_url": filing_detail_url,
            "document_type": None, "document_description": None, "document_url": None,
            "matched": False, "error": str(e),
        })
    time.sleep(0.2)

pd.DataFrame(all_results).to_csv(output_dir / "filings_8k_assessment.csv", index=False)

results_df = pd.DataFrame(all_results)
results_df = results_df[results_df["matched"] == True]
results_df = results_df[results_df["document_type"] == "8-K"]
results_df = results_df[["symbol", "filingDate", "filing_detail_url", "document_type"]]
results_df.to_csv(output_dir / "filings_8k_assessment_matched.csv", index=False)
# Out:
# [1/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [2/448] Assessing: SSGC | 2026-05-22 00:00:00
#   No match
# [3/448] Assessing: HITC | 2026-05-22 00:00:00
#   No match
# [4/448] Assessing: POLA | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [5/448] Assessing: HRYU | 2026-05-22 00:00:00
#   No match
# [6/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [7/448] Assessing: MLND | 2026-05-22 00:00:00
#   No match
# [8/448] Assessing: TPST | 2026-05-22 00:00:00
#   No match
# [9/448] Assessing: LVWR-WT | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [10/448] Assessing: LVWR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [11/448] Assessing: LASE | 2026-05-22 00:00:00
#   No match
# [12/448] Assessing: RYES | 2026-05-22 00:00:00
#   No match
# [13/448] Assessing: DPDW | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [14/448] Assessing: APUR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [15/448] Assessing: MAZE | 2026-05-22 00:00:00
#   No match
# [16/448] Assessing: UNMA | 2026-05-22 00:00:00
#   No match
# [17/448] Assessing: UNM | 2026-05-22 00:00:00
#   No match
# [18/448] Assessing: MUX | 2026-05-22 00:00:00
#   No match
# [19/448] Assessing: NUVR | 2026-05-22 00:00:00
#   No match
# [20/448] Assessing: JAGX | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [21/448] Assessing: IMII | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [22/448] Assessing: BSAI | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [23/448] Assessing: VHNAU | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [24/448] Assessing: VHNA | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [25/448] Assessing: RDZN | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [26/448] Assessing: VHNAW | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
#
| 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [134/448] Assessing: SRFM | 2026-05-22 00:00:00
#   No match
# [135/448] Assessing: DFPHU | 2026-05-22 00:00:00
#   No match
# [136/448] Assessing: DFPHW | 2026-05-22 00:00:00
#   No match
# [137/448] Assessing: TOI | 2026-05-22 00:00:00
#   No match
# [138/448] Assessing: GIPR | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [139/448] Assessing: GIPRW | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [140/448] Assessing: OBT | 2026-05-22 00:00:00
#   No match
# [141/448] Assessing: TOIIW | 2026-05-22 00:00:00
#   No match
# [142/448] Assessing: TRGP | 2026-05-22 00:00:00
#   No match
# [143/448] Assessing: ESTA | 2026-05-22 00:00:00
#   No match
# [144/448] Assessing: HOPE | 2026-05-22 00:00:00
#   No match
# [145/448] Assessing: WING | 2026-05-22 00:00:00
#   No match
# [146/448] Assessing: BKV | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [147/448] Assessing: LGL-WT | 2026-05-22 00:00:00
#   No match
# [148/448] Assessing: LGL | 2026-05-22 00:00:00
#   No match
# [149/448] Assessing: SATS | 2026-05-22 00:00:00
#   No match
# [150/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [151/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [152/448] Assessing: VNO-PM | 2026-05-22 00:00:00
#   No match
# [153/448] Assessing: VNO | 2026-05-22 00:00:00
#   No match
# [154/448] Assessing: VNORP | 2026-05-22 00:00:00
#   No match
# [155/448] Assessing: VNO-PO | 2026-05-22 00:00:00
#   No match
# [156/448] Assessing: VNO-PL | 2026-05-22 00:00:00
#   No match
# [157/448] Assessing: VNO-PN | 2026-05-22 00:00:00
#   No match
# [158/448] Assessing: BXP | 2026-05-22 00:00:00
#   No match
# [159/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [160/448] Assessing: LEG | 2026-05-22 00:00:00
#   No match
# [161/448] Assessing: BHR-PB | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [162/448] Assessing: BHR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [163/448] Assessing: BHR-PD | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [164/448] Assessing: MWRK | 2026-05-22 00:00:00
#   No match
# [165/448] Assessing: WAST | 2026-05-22 00:00:00
#   No match
# [166/448] Assessing: CWRK | 2026-05-22 00:00:00
#   No match
# [167/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [168/448] Assessing: KDP | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [169/448] Assessing: AIZ | 2026-05-22 00:00:00
#   No match
# [170/448] Assessing: AIZN | 2026-05-22 00:00:00
#   No match
# [171/448] Assessing: RICK | 2026-05-22 00:00:00
#   No match
# [172/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [173/448] Assessing: IBTA | 2026-05-22 00:00:00
#   No match
# [174/448] Assessing: PAGP | 2026-05-22 00:00:00
#   No match
# [175/448] Assessing: MRK | 2026-05-22 00:00:00
#   No match
# [176/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [177/448] Assessing: UAL | 2026-05-22 00:00:00
#   No match
# [178/448] Assessing: PAA | 2026-05-22 00:00:00
#   No match
# [179/448] Assessing: LOKB | 2026-05-22 00:00:00
#   No match
# [180/448] Assessing: NVTSW | 2026-05-22 00:00:00
#   No match
# [181/448] Assessing: NVTS | 2026-05-22 00:00:00
#   No match
# [182/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [183/448] Assessing: AHT-PH | 2026-05-22 00:00:00
#   No match
# [184/448] Assessing: AHT-PI | 2026-05-22 00:00:00
#   No match
# [185/448] Assessing: AHT-PG | 2026-05-22 00:00:00
#   No match
# [186/448] Assessing: AHT | 2026-05-22 00:00:00
#   No match
# [187/448] Assessing: AHT-PD | 2026-05-22 00:00:00
#   No match
# [188/448] Assessing: AHT-PF | 2026-05-22 00:00:00
 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [244/448] Assessing: FLT | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [245/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [246/448] Assessing: AMAL | 2026-05-22 00:00:00
#   No match
# [247/448] Assessing: MTZ | 2026-05-22 00:00:00
#   No match
# [248/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [249/448] Assessing: AMZN | 2026-05-22 00:00:00
#   No match
# [250/448] Assessing: PACK | 2026-05-22 00:00:00
#   No match
# [251/448] Assessing: BKSY | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [252/448] Assessing: BKSY-WT | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [253/448] Assessing: SFTW | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [254/448] Assessing: IIPR-PA | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [255/448] Assessing: IIPR | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [256/448] Assessing: DNTH | 2026-05-22 00:00:00
#   No match
# [257/448] Assessing: MGTA | 2026-05-22 00:00:00
#   No match
# [258/448] Assessing: CB | 2026-05-22 00:00:00
#   No match
# [259/448] Assessing: SHC | 2026-05-22 00:00:00
#   No match
# [260/448] Assessing: FTLF | 2026-05-22 00:00:00
#   No match
# [261/448] Assessing: O | 2026-05-22 00:00:00
#   No match
# [262/448] Assessing: OMI | 2026-05-22 00:00:00
#   No match
# [263/448] Assessing: ACH | 2026-05-22 00:00:00
#   No match
# [264/448] Assessing: LOB | 2026-05-22 00:00:00
#   No match
# [265/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [266/448] Assessing: SSNC | 2026-05-22 00:00:00
#   No match
# [267/448] Assessing: CTRI | 2026-05-22 00:00:00
#   No match
# [268/448] Assessing: SBMT | 2026-05-22 00:00:00
#   No match
# [269/448] Assessing: BLBX | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [270/448] Assessing: AKA | 2026-05-22 00:00:00
#   No match
# [271/448] Assessing: BUSE | 2026-05-22 00:00:00
#   No match
# [272/448] Assessing: TCRX | 2026-05-22 00:00:00
#   No match
# [273/448] Assessing: LYB | 2026-05-22 00:00:00
#   No match
# [274/448] Assessing: DEVS | 2026-05-22 00:00:00
#   No match
# [275/448] Assessing: FIAC | 2026-05-22 00:00:00
#   No match
# [276/448] Assessing: FIACU | 2026-05-22 00:00:00
#   No match
# [277/448] Assessing: FIACW | 2026-05-22 00:00:00
#   No match
# [278/448] Assessing: KDLYW | 2026-05-22 00:00:00
#   No match
# [279/448] Assessing: NAKA | 2026-05-22 00:00:00
#   No match
# [280/448] Assessing: NAKAW | 2026-05-22 00:00:00
#   No match
# [281/448] Assessing: KDLY | 2026-05-22 00:00:00
#   No match
# [282/448] Assessing: NSPR | 2026-05-22 00:00:00
#   No match
# [283/448] Assessing: LQR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [284/448] Assessing: YHC | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [285/448] Assessing: PLMIU | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [286/448] Assessing: PLMIW | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [287/448] Assessing: PLMI | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [288/448] Assessing: ANZUW | 2026-05-22 00:00:00
#   No match
# [289/448] Assessing: ANZU | 2026-05-22 00:00:00
#   No match
# [290/448] Assessing: ANZUU | 2026-05-22 00:00:00
#   No match
# [291/448] Assessing: COCHW | 2026-05-22 00:00:00
#   No match
# [292/448] Assessing: COCH | 2026-05-22 00:00:00
#   No match
# [293/448] Assessing: HGV | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [294/448] Assessing: UGI | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [295/448] Assessing: UGIC | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [296/448] Assessing: PUMP | 2026-05-22 00:00:00
#   No match
# [297/448] Assessing: TWOH | 2026-05-22 00:00:00
#   No match
# [298/448] Assessing: DV | 2026-05-22 00:00:00
#   No match
# [299/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [300/448] Assessing: BATRA | 2026-05-22 00:00:00
#   No match
# [301/448] Assessing: BATRK | 2026-05-22 00:00:00
#   No match
# [302/448] Assessing: BATRB | 2026-05-22 00:00:00
#   No match
# [303/448] Assessing: BBNX | 2026-05-22 00:00:00
#   No match
# [304/448] Assessing: FENC | 2026-05-22 00:00:00
#   No match
# [305/448] Assessing: WEN | 2026-05-22 00:00:00
#   No match
# [306/448] Assessing: PORT-WT | 2026-05-22 00:00:00
#   No match
# [307/448] Assessing: PORT | 2026-05-22 00:00:00
#   No match
# [308/448] Assessing: PORT-UN | 2026-05-22 00:00:00
#   No match
# [309/448] Assessing: ITW | 2026-05-22 00:00:00
#   No match
# [310/448] Assessing: CRIS | 2026-05-22 00:00:00
#   No match
# [311/448] Assessing: MRSH | 2026-05-22 00:00:00
#   No match
# [312/448] Assessing: MMC | 2026-05-22 00:00:00
#   No match
# [313/448] Assessing: FCAP | 2026-05-22 00:00:00
#   No match
# [314/448] Assessing: STHO | 2026-05-22 00:00:00
#   No match
# [315/448] Assessing: SNSE | 2026-05-22 00:00:00
#   No match
# [316/448] Assessing: USAU | 2026-05-22 00:00:00
#   No match
# [317/448] Assessing: AAP | 2026-05-22 00:00:00
#   No match
# [318/448] Assessing: APH | 2026-05-22 00:00:00
#   No match
# [319/448] Assessing: KIDZW | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [320/448] Assessing: KIDZ | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [321/448] Assessing: TEM | 2026-05-22 00:00:00
#   No match
# [322/448] Assessing: NINEQ | 2026-05-22 00:00:00
#   No match
# [323/448] Assessing: MBRX | 2026-05-22 00:00:00
#   No match
# [324/448] Assessing: OPCH | 2026-05-22 00:00:00
#   No match
# [325/448] Assessing: COLAU | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [326/448] Assessing: COLAR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [327/448] Assessing: COLA | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [328/448] Assessing: BY | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [329/448] Assessing: MCBS | 2026-05-22 00:00:00
#   No match
# [330/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [331/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [332/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [333/448] Assessing: HL | 2026-05-22 00:00:00
#   No match
# [334/448] Assessing: HL-PB | 2026-05-22 00:00:00
#   No match
# [335/448] Assessing: EVEX | 2026-05-22 00:00:00
#   No match
# [336/448] Assessing: EVEX-WT | 2026-05-22 00:00:00
#   No match
# [337/448] Assessing: ZNTEU | 2026-05-22 00:00:00
#   No match
# [338/448] Assessing: ZNTE | 2026-05-22 00:00:00
#   No match
# [339/448] Assessing: GPJA | 2026-05-22 00:00:00
#   No match
# [340/448] Assessing: CMTV | 2026-05-22 00:00:00
#   No match
# [341/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [342/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [343/448] Assessing: GRVE | 2026-05-22 00:00:00
#   No match
# [344/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [345/448] Assessing: NOV | 2026-05-22 00:00:00
#   No match
# [346/448] Assessing: EEFT | 2026-05-22 00:00:00
#   No match
# [347/448] Assessing: CVBF | 2026-05-22 00:00:00
#   No match
# [348/448] Assessing: FGBI | 2026-05-22 00:00:00
#   No match
# [349/448] Assessing: FGBIP | 2026-05-22 00:00:00
#   No match
# [350/448] Assessing: HBCP | 2026-05-22 00:00:00
#   No match
# [351/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [352/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [353/448] Assessing: RBB | 2026-05-22 00:00:00
#   No match
# [354/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [355/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 3 document(s)
# [356/448] Assessing: ULS | 2026-05-22 00:00:00
#   No match
# [357/448] Assessing: GRNT-WT | 2026-05-22 00:00:00
#   No match
# [358/448] Assessing: GRNT | 2026-05-22 00:00:00
#   No match
# [359/448] Assessing: FTCO | 2026-05-22 00:00:00
#   No match
# [360/448] Assessing: TNL | 2026-05-22 00:00:00
#   No match
# [361/448] Assessing: FSTR | 2026-05-22 00:00:00
#   No match
# [362/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [363/448] Assessing: UWHR | 2026-05-22 00:00:00
#   No match
# [364/448] Assessing: BCSF | 2026-05-22 00:00:00
#   No match
# [365/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [366/448] Assessing: BCML | 2026-05-22 00:00:00
#   No match
# [367/448] Assessing: SMP | 2026-05-22 00:00:00
#   No match
# [368/448] Assessing: AEL-PB | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [369/448] Assessing: AEL | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [370/448] Assessing: AEL-PA | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [371/448] Assessing: MGEE | 2026-05-22 00:00:00
#   No match
# [372/448] Assessing: HST | 2026-05-22 00:00:00
#   No match
# [373/448] Assessing: CVCO | 2026-05-22 00:00:00
#   No match
# [374/448] Assessing: MCD | 2026-05-22 00:00:00
#   No match
# [375/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [376/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [377/448] Assessing: DVN | 2026-05-22 00:00:00
#   No match
# [378/448] Assessing: PFS | 2026-05-22 00:00:00
#   No match
# [379/448] Assessing: COSM | 2026-05-22 00:00:00
#   No match
# [380/448] Assessing: WTMAU | 2026-05-22 00:00:00
#   No match
# [381/448] Assessing: WTMA | 2026-05-22 00:00:00
#   No match
# [382/448] Assessing: WTMAR | 2026-05-22 00:00:00
#   No match
# [383/448] Assessing: MNSB | 2026-05-22 00:00:00
#   No match
# [384/448] Assessing: MNSBP | 2026-05-22 00:00:00
#   No match
# [385/448] Assessing: GDLC | 2026-05-22 00:00:00
#   No match
# [386/448] Assessing: LTCN | 2026-05-22 00:00:00
#   No match
# [387/448] Assessing: NMRK | 2026-05-22 00:00:00
#   No match
# [388/448] Assessing: FFBC | 2026-05-22 00:00:00
#   No match
# [389/448] Assessing: EVMN | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [390/448] Assessing: MEHA | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [391/448] Assessing: ONCY | 2026-05-22 00:00:00
#   No match
# [392/448] Assessing: SHBI | 2026-05-22 00:00:00
#   No match
# [393/448] Assessing: COFS | 2026-05-22 00:00:00
#   No match
# [394/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [395/448] Assessing: TXRH | 2026-05-22 00:00:00
#   No match
# [396/448] Assessing: IPW | 2026-05-22 00:00:00
#   No match
# [397/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [398/448] Assessing: ACMR | 2026-05-22 00:00:00
#   No match
# [399/448] Assessing: ONDS | 2026-05-22 00:00:00
#   No match
# [400/448] Assessing: PRK | 2026-05-22 00:00:00
#   No match
# [401/448] Assessing: FITB | 2026-05-22 00:00:00
#   No match
# [402/448] Assessing: FITBP | 2026-05-22 00:00:00
#   No match
# [403/448] Assessing: FITBO | 2026-05-22 00:00:00
#   No match
# [404/448] Assessing: FITBI | 2026-05-22 00:00:00
#   No match
# [405/448] Assessing: PKBK | 2026-05-22 00:00:00
#   No match
# [406/448] Assessing: GRIL | 2026-05-22 00:00:00
#   No match
# [407/448] Assessing: SPWR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [408/448] Assessing: SPWRW | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [409/448] Assessing: FACT-UN | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [410/448] Assessing: CSLRW | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [411/448] Assessing: CSLR | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [412/448] Assessing: FACT-WT | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [413/448] Assessing: CREG | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [414/448] Assessing: MCFT | 2026-05-22 00:00:00
#   No match
# [415/448] Assessing: AVXL | 2026-05-22 00:00:00
#   No match
# [416/448] Assessing: SEER | 2026-05-22 00:00:00
#   No match
# [417/448] Assessing: BG | 2026-05-22 00:00:00
#   No match
# [418/448] Assessing: TIPT | 2026-05-22 00:00:00
#   No match
# [419/448] Assessing: KIM-PL | 2026-05-22 00:00:00
#   No match
# [420/448] Assessing: None | 2026-05-22 00:00:00
#   No match
# [421/448] Assessing: KIM-PM | 2026-05-22 00:00:00
#   No match
# [422/448] Assessing: KIM-PN | 2026-05-22 00:00:00
#   No match
# [423/448] Assessing: KIM | 2026-05-22 00:00:00
#   No match
# [424/448] Assessing: PRVA | 2026-05-22 00:00:00
#   No match
# [425/448] Assessing: GTBP | 2026-05-22 00:00:00
#   No match
# [426/448] Assessing: HSIC | 2026-05-22 00:00:00
#   No match
# [427/448] Assessing: ENRT | 2026-05-22 00:00:00
#   No match
# [428/448] Assessing: UHID | 2026-05-22 00:00:00
#   No match
# [429/448] Assessing: UHS | 2026-05-22 00:00:00
#   No match
# [430/448] Assessing: STIM | 2026-05-22 00:00:00
#   No match
# [431/448] Assessing: BJ | 2026-05-22 00:00:00
#   No match
# [432/448] Assessing: ASMB | 2026-05-22 00:00:00
#   No match
# [433/448] Assessing: CAPNU | 2026-05-22 00:00:00
#   No match
# [434/448] Assessing: CAPN | 2026-05-22 00:00:00
#   No match
# [435/448] Assessing: CAPNR | 2026-05-22 00:00:00
#   No match
# [436/448] Assessing: BAH | 2026-05-22 00:00:00
#   MATCH: 1 document(s)
# [437/448] Assessing: W | 2026-05-22 00:00:00
#   No match
# [438/448] Assessing: None | 2026-05-22 00:00:00
#   MATCH: 2 document(s)
# [439/448] Assessing: GSIT | 2026-05-22 00:00:00
#   No match
# [440/448] Assessing: MAIA | 2026-05-22 00:00:00
#   No match
# [441/448] Assessing: MNTS | 2026-05-22 00:00:00
#   No match
# [442/448] Assessing: MNTSW | 2026-05-22 00:00:00
#   No match
# [443/448] Assessing: SRACW | 2026-05-22 00:00:00
#   No match
# [444/448] Assessing: SRACU | 2026-05-22 00:00:00
#   No match
# [445/448] Assessing: SRAC | 2026-05-22 00:00:00
#   No match
# [446/448] Assessing: XOMAO | 2026-05-22 00:00:00
#   No match
# [447/448] Assessing: XOMAP | 2026-05-22 00:00:00
#   No match
# [448/448] Assessing: XOMA | 2026-05-22 00:00:00
#   No match
